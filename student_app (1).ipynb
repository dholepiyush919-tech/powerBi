# %%
#student managing app
students = {}
print("\n***STUDENT MANAGER APP***")

while True:
  print("1.add student")
  print("2.view student")
  print("3.check result")
  print("4.exit")

  choice = int(input("enter no. here(1/2/3/4):"))

  if choice == 1:
    name = str(input("enter name here:"))
    marks = int(input("enter marks here"))
    students[name]=marks

    print(f"{name} successfully added!")

  elif choice == 2:
    name = str(input("enter name here:"))
    if name in students:
      print(f"{name} is exist")
    else:
      print(f"{name} username not found")

  elif choice == 3:
    name = str(input("enter name here:"))
    if name in students:
      if marks >= 40:
        print(f"{name} pass!")
      else:
        print(f"{name} fail!")
    else:
      print("user not found")
  elif choice == 4:
    print("existing...")
    break

  else:
    print("error!")
# Out:
# ***STUDENT MANAGER APP***
# 1.add student
# 2.view student
# 3.check result
# 4.exit
# enter no. here(1/2/3/4):1
# enter name here:piyush
# enter marks here70
# piyush successfully added!
# 1.add student
# 2.view student
# 3.check result
# 4.exit
# enter no. here(1/2/3/4):2
# enter name here:piyush
# piyush is exist
# 1.add student
# 2.view student
# 3.check result
# 4.exit
# enter no. here(1/2/3/4):3
# enter name here:piyush
# piyush pass!
# 1.add student
# 2.view student
# 3.check result
# 4.exit
# enter no. here(1/2/3/4):4
# existing...
