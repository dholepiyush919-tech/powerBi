# %%
#RENT CALCULATOR
persons = int(input("enter persons living in the flat:"))
rent  = int(input("enter  flat rent:"))
mess  = int(input("enter food fee:"))
electricity_bill  = int(input("enter ebill:"))
wifi_bill  = int(input("enter wifi bill:"))

total_bill = (rent+mess+electricity_bill+wifi_bill)
output = (total_bill)//persons
print(f"your total months expand is {total_bill} and to each roomate have to pay {output} each month")
# Out:
# enter persons living in the flat:4
# enter  flat rent:8500
# enter food fee:4000
# enter ebill:2100
# enter wifi bill:404
# your total months expand is 15004 and to each roomate have to pay 3751 each month
