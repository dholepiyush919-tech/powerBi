# %%
#student managing app
students = {}
print("\n***STUDENT MANAGER APP***")

while True:
  print("1.add student")
  print("2.view student")
  print("3.check result")
  print("4.exit")

  choice = int(input("enter no. here(1/2/3/4):"))

  if choice == 1:
    name = str(input("enter name here:"))
    marks = int(input("enter marks here"))
    students[name]=marks

    print(f"{name} successfully added!")

  elif choice == 2:
    name = str(input("enter name here:"))
    if name in students:
      print(f"{name} is exist")
    else:
      print(f"{name} username not found")

  elif choice == 3:
    name = str(input("enter name here:"))
    if name in students:
      if marks >= 40:
        print(f"{name} pass!")
      else:
        print(f"{name} fail!")
    else:
      print("user not found")
  elif choice == 4:
    print("existing...")
    break

  else:
    print("error!")
# Out:
# ***STUDENT MANAGER APP***
# 1.add student
# 2.view student
# 3.check result
# 4.exit
# mathan successfully added!
# 1.add student
# 2.view student
# 3.check result
# 4.exit
# gunjan successfully added!
# 1.add student
# 2.view student
# 3.check result
# 4.exit
# piyush successfully added!
# 1.add student
# 2.view student
# 3.check result
# 4.exit
# dipanshu successfully added!
# 1.add student
# 2.view student
# 3.check result
# 4.exit
# manthan username not found
# 1.add student
# 2.view student
# 3.check result
# 4.exit
# mathan is exist
# 1.add student
# 2.view student
# 3.check result
# 4.exit
# mathan pass!
# 1.add student
# 2.view student
# 3.check result
# 4.exit
# manthan successfully added!
# 1.add student
# 2.view student
# 3.check result
# 4.exit
# manthan fail!
# 1.add student
# 2.view student
# 3.check result
# 4.exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4052/2080775553.py in <cell line: 0>()
#       9   print("4.exit")
#      10
# ---> 11   choice = int(input("enter no. here(1/2/3/4):"))
#      12
#      13   if choice == 1:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
